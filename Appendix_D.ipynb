# %% [markdown]
# <a href="https://colab.research.google.com/github/CarolineJoi3375/RTA/blob/main/Appendix_D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#Support Vector Machine One-Versus-One (OVO)

# Load libraries
import pandas as pd
import numpy as np
from sklearn.svm import SVC # Import SVC
from sklearn.multiclass import OneVsOneClassifier # Import multiclass for SVM
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn.metrics import precision_score, accuracy_score
from sklearn.metrics import classification_report, f1_score


#Read in the dataset and display
dataset = pd.read_excel('/content/gdrive/MyDrive/Colab Notebooks/RTA_Final.xlsx')

#Feature selection: split the dataset into features (independent variables) and target (dependent variable)
feature_cols = ['easting', 'northing', 'number_of_vehicles', 'year', 'month', 'day','time_(24hr)','1st_road_class', 'road_surface',
'lighting_conditions', 'weather_conditions', 'sex_of_casualty', 'age_of_casualty', 'type_of_vehicle']
X = dataset[feature_cols] # Features
Y = dataset['casualty_severity'] # Target variable

#Function for split dataset will have 3 parameters: features, target, test_set size
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42) # 70% training and 30% test

# print the count of train dataset
print(y_train.value_counts())

#Build SVM OVO Model using Scikit Learn
SVM_OvO = OneVsOneClassifier(SVC())
# Train SVM Classifer
SVM_OvO = SVM_OvO.fit(X_train,y_train)
#Predict the response for test dataset
y_pred = SVM_OvO.predict(X_test)

#Evaluate the accuracy of the model for prediction
#Model Accuracy, how often is the classifier correct?
print("\n")
print("SVM One-Versus-One Accuracy:", metrics.accuracy_score(y_test, y_pred))

# classification report on test dataset
classif_re = classification_report(y_test, y_pred)
print(classif_re)
print("Precision:",metrics.precision_score(y_test, y_pred, average='weighted'))
print("Recall:",metrics.recall_score(y_test, y_pred, average='weighted'))
print("f1 Score:",metrics.f1_score(y_test, y_pred, average='weighted'))
#print("\n")
# Out:
# casualty_severity
# 3    16817
# 2     2308
# 1      150
# Name: count, dtype: int64
#
#
# SVM One-Versus-One Accuracy: 0.8689020699673163
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        58
#            2       0.00      0.00      0.00      1025
#            3       0.87      1.00      0.93      7178
#
#     accuracy                           0.87      8261
#    macro avg       0.29      0.33      0.31      8261
# weighted avg       0.75      0.87      0.81      8261
#
# Precision: 0.754990807193487
# Recall: 0.8689020699673163
# f1 Score: 0.8079511701827057
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#Support Vector Machine One-Versus-All (OVA)

# Load libraries
import pandas as pd
import numpy as np
from sklearn.svm import SVC # Import SVC
from sklearn.multiclass import OneVsRestClassifier # Import multiclass for SVM
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn.metrics import precision_score, accuracy_score
from sklearn.metrics import classification_report, f1_score


#Read in the dataset and display
dataset = pd.read_excel('/content/gdrive/MyDrive/Colab Notebooks/RTA_Final.xlsx')

#Feature selection: split the dataset into features (independent variables) and target (dependent variable)
feature_cols = ['easting', 'northing', 'number_of_vehicles', 'year', 'month', 'day','time_(24hr)','1st_road_class', 'road_surface',
'lighting_conditions', 'weather_conditions', 'sex_of_casualty', 'age_of_casualty', 'type_of_vehicle']
X = dataset[feature_cols] # Features
Y = dataset['casualty_severity'] # Target variable

#Function for split dataset will have 3 parameters: features, target, test_set size
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42) # 70% training and 30% test

# print the count of train dataset
print(y_train.value_counts())

#Build SVM OVA Model using Scikit Learn
SVM_OvA = OneVsRestClassifier(SVC())
# Train SVM Classifer
SVM_OvA = SVM_OvA.fit(X_train,y_train)
#Predict the response for test dataset
y_pred = SVM_OvA.predict(X_test)

#Evaluate the accuracy of the model for prediction
#Model Accuracy, how often is the classifier correct?
print("\n")
print("SVM One-Versus-All Accuracy:", metrics.accuracy_score(y_test, y_pred))

# classification report on test dataset
classif_re = classification_report(y_test, y_pred)
print(classif_re)
print("Precision:",metrics.precision_score(y_test, y_pred, average='weighted'))
print("Recall:",metrics.recall_score(y_test, y_pred, average='weighted'))
print("f1 Score:",metrics.f1_score(y_test, y_pred, average='weighted'))
#print("\n")
# Out:
# casualty_severity
# 3    16817
# 2     2308
# 1      150
# Name: count, dtype: int64
#
#
# SVM One-Versus-All Accuracy: 0.8689020699673163
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        58
#            2       0.00      0.00      0.00      1025
#            3       0.87      1.00      0.93      7178
#
#     accuracy                           0.87      8261
#    macro avg       0.29      0.33      0.31      8261
# weighted avg       0.75      0.87      0.81      8261
#
# Precision: 0.754990807193487
# Recall: 0.8689020699673163
# f1 Score: 0.8079511701827057
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#Support Vector Machine One-Versus-One (OVO) with Normalisation

# Load libraries
import pandas as pd
import numpy as np
from sklearn.svm import SVC # Import SVC
from sklearn.multiclass import OneVsOneClassifier # Import multiclass for SVM
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn.metrics import precision_score, accuracy_score
from sklearn.metrics import classification_report, f1_score

#Read in the dataset and display
dataset = pd.read_excel('/content/gdrive/MyDrive/Colab Notebooks/RTA_Final.xlsx')

#Feature selection: split the dataset into features (independent variables) and target (dependent variable)
feature_cols = ['easting', 'northing', 'number_of_vehicles', 'year', 'month', 'day','time_(24hr)','1st_road_class', 'road_surface',
'lighting_conditions', 'weather_conditions', 'sex_of_casualty', 'age_of_casualty', 'type_of_vehicle']
X = dataset[feature_cols] # Features
Y = dataset['casualty_severity'] # Target variable

#Function for split dataset will have 3 parameters: features, target, test_set size
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42) # 70% training and 30% test

# import module of MinMaxScaler
from sklearn.preprocessing import MinMaxScaler

# define MinMaxScaler
minmax_scaler = MinMaxScaler()
# transform data
X_train_minmax = minmax_scaler.fit_transform(X_train)
X_test_minmax = minmax_scaler.transform(X_test)

#Build SVM OVO Model using Scikit Learn
SVM_OvO = OneVsOneClassifier(SVC(random_state=42))
# Train SVM Classifer
SVM_OvO_minmax = SVM_OvO.fit(X_train_minmax,y_train)
#Predict the response for test dataset
y_pred = SVM_OvO_minmax.predict(X_test_minmax)

#Evaluate the accuracy of the model for prediction
#Model Accuracy, how often is the classifier correct?
print("\n")
print("SVM OVO with Normalisation Accuracy:", metrics.accuracy_score(y_test, y_pred))

# classification report on test dataset
classif_re = classification_report(y_test, y_pred)
print(classif_re)
print("Precision:",metrics.precision_score(y_test, y_pred, average='weighted'))
print("Recall:",metrics.recall_score(y_test, y_pred, average='weighted'))
print("f1 Score:",metrics.f1_score(y_test, y_pred, average='weighted'))
#print("\n")
# Out:
# SVM OVO with Normalisation Accuracy: 0.8689020699673163
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        58
#            2       0.00      0.00      0.00      1025
#            3       0.87      1.00      0.93      7178
#
#     accuracy                           0.87      8261
#    macro avg       0.29      0.33      0.31      8261
# weighted avg       0.75      0.87      0.81      8261
#
# Precision: 0.754990807193487
# Recall: 0.8689020699673163
# f1 Score: 0.8079511701827057
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#Support Vector Machine One-Versus-All (OVA) with Normalisation

# Load libraries
import pandas as pd
import numpy as np
from sklearn.svm import SVC # Import SVC
from sklearn.multiclass import OneVsRestClassifier # Import multiclass for SVM
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn.metrics import precision_score, accuracy_score
from sklearn.metrics import classification_report, f1_score

#Read in the dataset and display
dataset = pd.read_excel('/content/gdrive/MyDrive/Colab Notebooks/RTA_Final.xlsx')

#Feature selection: split the dataset into features (independent variables) and target (dependent variable)
feature_cols = ['easting', 'northing', 'number_of_vehicles', 'year', 'month', 'day','time_(24hr)','1st_road_class', 'road_surface',
'lighting_conditions', 'weather_conditions', 'sex_of_casualty', 'age_of_casualty', 'type_of_vehicle']
X = dataset[feature_cols] # Features
Y = dataset['casualty_severity'] # Target variable

#Function for split dataset will have 3 parameters: features, target, test_set size
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42) # 70% training and 30% test

# import module of MinMaxScaler
from sklearn.preprocessing import MinMaxScaler

# define MinMaxScaler
minmax_scaler = MinMaxScaler()
# transform data
X_train_minmax = minmax_scaler.fit_transform(X_train)
X_test_minmax = minmax_scaler.transform(X_test)

#Build SVM OVO Model using Scikit Learn
SVM_OvA = OneVsRestClassifier(SVC(random_state=42))
# Train SVM Classifer
SVM_OvA_minmax = SVM_OvA.fit(X_train_minmax,y_train)
#Predict the response for test dataset
y_pred = SVM_OvA_minmax.predict(X_test_minmax)

#Evaluate the accuracy of the model for prediction
#Model Accuracy, how often is the classifier correct?
print("\n")
print("SVM OVA with Normalisation Accuracy:", metrics.accuracy_score(y_test, y_pred))

# classification report on test dataset
classif_re = classification_report(y_test, y_pred)
print(classif_re)
print("Precision:",metrics.precision_score(y_test, y_pred, average='weighted'))
print("Recall:",metrics.recall_score(y_test, y_pred, average='weighted'))
print("f1 Score:",metrics.f1_score(y_test, y_pred, average='weighted'))
#print("\n")
# Out:
# SVM OVA with Normalisation Accuracy: 0.8689020699673163
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        58
#            2       0.00      0.00      0.00      1025
#            3       0.87      1.00      0.93      7178
#
#     accuracy                           0.87      8261
#    macro avg       0.29      0.33      0.31      8261
# weighted avg       0.75      0.87      0.81      8261
#
# Precision: 0.754990807193487
# Recall: 0.8689020699673163
# f1 Score: 0.8079511701827057
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#Support Vector Machine One-Versus-One (OVO) with SMOTE

# Load libraries
import pandas as pd
import numpy as np
from sklearn.svm import SVC # Import SVC
from sklearn.multiclass import OneVsOneClassifier # Import multiclass for SVM
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn.metrics import precision_score, accuracy_score
from sklearn.metrics import classification_report, f1_score


#Read in the dataset and display
dataset = pd.read_excel('/content/gdrive/MyDrive/Colab Notebooks/RTA_Final.xlsx')

#Feature selection: split the dataset into features (independent variables) and target (dependent variable)
feature_cols = ['easting', 'northing', 'number_of_vehicles', 'year', 'month', 'day','time_(24hr)','1st_road_class', 'road_surface',
'lighting_conditions', 'weather_conditions', 'sex_of_casualty', 'age_of_casualty', 'type_of_vehicle']
X = dataset[feature_cols] # Features
Y = dataset['casualty_severity'] # Target variable

#Function for split dataset will have 3 parameters: features, target, test_set size
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42) # 70% training and 30% test

# We can use the SMOTE algorithm to oversample the minority class.
from imblearn.over_sampling import SMOTE
# Create an instance of the SMOTE algorithm
smote = SMOTE()
# Oversample the minority class
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# print the count of train dataset
print("Before SMOTE:",y_train.value_counts())
print("After SMOTE:",y_train_smote.value_counts())

#Build SVM OVO Model using Scikit Learn
SVMsmote_OvO = OneVsOneClassifier(SVC(random_state=42))
# Train SVM Classifer
SVMsmote_OvO = SVMsmote_OvO.fit(X_train_smote,y_train_smote)
#Predict the response for test dataset
y_pred = SVMsmote_OvO.predict(X_test)

#Evaluate the accuracy of the model for prediction
#Model Accuracy, how often is the classifier correct?
print("\n")
print("SVM One-Versus-One with SMOTE Accuracy:", metrics.accuracy_score(y_test, y_pred))

# classification report on test dataset
classif_re = classification_report(y_test, y_pred)
print(classif_re)
print("Precision:",metrics.precision_score(y_test, y_pred, average='weighted'))
print("Recall:",metrics.recall_score(y_test, y_pred, average='weighted'))
print("f1 Score:",metrics.f1_score(y_test, y_pred, average='weighted'))
#print("\n")
# Out:
# Before SMOTE: casualty_severity
# 3    16817
# 2     2308
# 1      150
# Name: count, dtype: int64
# After SMOTE: casualty_severity
# 2    16817
# 3    16817
# 1    16817
# Name: count, dtype: int64
#
#
# SVM One-Versus-One with SMOTE Accuracy: 0.761287979663479
#               precision    recall  f1-score   support
#
#            1       0.01      0.17      0.02        58
#            2       0.00      0.00      0.00      1025
#            3       0.87      0.87      0.87      7178
#
#     accuracy                           0.76      8261
#    macro avg       0.29      0.35      0.30      8261
# weighted avg       0.76      0.76      0.76      8261
#
# Precision: 0.7563517108000262
# Recall: 0.761287979663479
# f1 Score: 0.7583036443406382

# %%
#Support Vector Machine One-Versus-All (OVA) with SMOTE

# Load libraries
import pandas as pd
import numpy as np
from sklearn.svm import SVC # Import SVC
from sklearn.multiclass import OneVsRestClassifier # Import multiclass for SVM
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn.metrics import precision_score, accuracy_score
from sklearn.metrics import classification_report, f1_score


#Read in the dataset and display
dataset = pd.read_excel('/content/gdrive/MyDrive/Colab Notebooks/RTA_Final.xlsx')

#Feature selection: split the dataset into features (independent variables) and target (dependent variable)
feature_cols = ['easting', 'northing', 'number_of_vehicles', 'year', 'month', 'day','time_(24hr)','1st_road_class', 'road_surface',
'lighting_conditions', 'weather_conditions', 'sex_of_casualty', 'age_of_casualty', 'type_of_vehicle']
X = dataset[feature_cols] # Features
Y = dataset['casualty_severity'] # Target variable

#Function for split dataset will have 3 parameters: features, target, test_set size
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42) # 70% training and 30% test

# We can use the SMOTE algorithm to oversample the minority class.
from imblearn.over_sampling import SMOTE
# Create an instance of the SMOTE algorithm
smote = SMOTE()
# Oversample the minority class
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# print the count of train dataset
print("Before SMOTE:",y_train.value_counts())
print("After SMOTE:",y_train_smote.value_counts())

#Build SVM OVO Model using Scikit Learn
SVMsmote_OvA = OneVsRestClassifier(SVC(random_state=42))
# Train SVM Classifer
SVMsmote_OvA = SVMsmote_OvA.fit(X_train_smote,y_train_smote)
#Predict the response for test dataset
y_pred = SVMsmote_OvA.predict(X_test)

#Evaluate the accuracy of the model for prediction
#Model Accuracy, how often is the classifier correct?
print("\n")
print("SVM One-Versus-All with SMOTE Accuracy:", metrics.accuracy_score(y_test, y_pred))

# classification report on test dataset
classif_re = classification_report(y_test, y_pred)
print(classif_re)
print("Precision:",metrics.precision_score(y_test, y_pred, average='weighted'))
print("Recall:",metrics.recall_score(y_test, y_pred, average='weighted'))
print("f1 Score:",metrics.f1_score(y_test, y_pred, average='weighted'))
#print("\n")
# Out:
# Before SMOTE: casualty_severity
# 3    16817
# 2     2308
# 1      150
# Name: count, dtype: int64
# After SMOTE: casualty_severity
# 2    16817
# 3    16817
# 1    16817
# Name: count, dtype: int64
#
#
# SVM One-Versus-All with SMOTE Accuracy: 0.711051930758988
#               precision    recall  f1-score   support
#
#            1       0.01      0.19      0.01        58
#            2       0.15      0.02      0.04      1025
#            3       0.87      0.81      0.84      7178
#
#     accuracy                           0.71      8261
#    macro avg       0.34      0.34      0.30      8261
# weighted avg       0.78      0.71      0.74      8261
#
# Precision: 0.7782232219190534
# Recall: 0.711051930758988
# f1 Score: 0.737009264678337
